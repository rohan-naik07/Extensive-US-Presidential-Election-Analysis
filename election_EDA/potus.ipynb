# %% [markdown]
# <a href="https://colab.research.google.com/github/rylp/prez/blob/master/potus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORTING NECCESSARY STUFF

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#CREATING DATAFRAME

#METHOD-1
#url='https://raw.githubusercontent.com/rylp/prez/master/1976-2016-president.csv'
#df=pd.read_csv(url)

#METHOD-2
df=pd.read_csv('1976-2016-president.csv')

df.head(10)
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  Alabama       AL           1         63        41  US President
# 1  1976  Alabama       AL           1         63        41  US President
# 2  1976  Alabama       AL           1         63        41  US President
# 3  1976  Alabama       AL           1         63        41  US President
# 4  1976  Alabama       AL           1         63        41  US President
# 5  1976  Alabama       AL           1         63        41  US President
# 6  1976  Alabama       AL           1         63        41  US President
# 7  1976   Alaska       AK           2         94        81  US President
# 8  1976   Alaska       AK           2         94        81  US President
# 9  1976   Alaska       AK           2         94        81  US President
#
#                  candidate                       party  writein  \
# 0            Carter, Jimmy                    democrat    False
# ...

# %%
df.shape #There are 3740 rows and 14 columns
df.describe() #general description
# Out:
#               year   state_fips    state_cen     state_ic  candidatevotes  \
# count  3740.000000  3740.000000  3740.000000  3740.000000    3.740000e+03
# mean   1996.021390    28.855882    53.874866    40.006150    3.151389e+05
# std      12.586011    15.637863    26.062865    22.756304    7.371322e+05
# min    1976.000000     1.000000    11.000000     1.000000    1.000000e+00
# 25%    1984.000000    17.000000    33.000000    22.000000    1.498750e+03
# 50%    1996.000000    28.000000    54.000000    42.000000    8.992000e+03
# 75%    2008.000000    42.000000    81.000000    61.000000    2.245050e+05
# max    2016.000000    56.000000    95.000000    82.000000    8.753788e+06
#
#          totalvotes     version  notes
# count  3.740000e+03      3740.0    0.0
# mean   2.214284e+06  20171015.0    NaN
# std    2.252806e+06         0.0    NaN
# min    1.235740e+05  20171015.0    NaN
# 25%    6.296560e+05  20171015.0    NaN
# 50%    1.533950e+06  20171015.0    NaN
# ...

# %%
#REMOVING UNNECESSARY COLUMNS FROM DATASET like office

df[df.office != 'US President']
#now as no data elemnet has anything other than US President for 'office' column, we can delete it
# Out:
# Empty DataFrame
# Columns: [year, state, state_po, state_fips, state_cen, state_ic, office, candidate, party, writein, candidatevotes, totalvotes, version, notes]
# Index: []

# %%
df.drop(['office'],axis=1,inplace=True) 
#using drop() fn with axis=1 to specify column and inplace=True to state that replace the current dataset with this

# %%
df
#now columns have become 13
#now, check for 'notes' column
# Out:
#       year    state state_po  state_fips  state_cen  state_ic  \
# 0     1976  Alabama       AL           1         63        41
# 1     1976  Alabama       AL           1         63        41
# 2     1976  Alabama       AL           1         63        41
# 3     1976  Alabama       AL           1         63        41
# 4     1976  Alabama       AL           1         63        41
# ...    ...      ...      ...         ...        ...       ...
# 3735  2016  Wyoming       WY          56         83        68
# 3736  2016  Wyoming       WY          56         83        68
# 3737  2016  Wyoming       WY          56         83        68
# 3738  2016  Wyoming       WY          56         83        68
# 3739  2016  Wyoming       WY          56         83        68
#
#                     candidate                       party  writein  \
# 0               Carter, Jimmy                    democrat    False
# 1                Ford, Gerald                  republican    False
# ...

# %%
df[df.notes.notnull()]
#so,here we check if there is any data row with 'notes' as notnull. We didnt find any. so delete it
# Out:
# Empty DataFrame
# Columns: [year, state, state_po, state_fips, state_cen, state_ic, candidate, party, writein, candidatevotes, totalvotes, version, notes]
# Index: []

# %%
df.drop(['notes'],axis=1,inplace=True)

# %%
df
#now columns have become 13
# Out:
#       year    state state_po  state_fips  state_cen  state_ic  \
# 0     1976  Alabama       AL           1         63        41
# 1     1976  Alabama       AL           1         63        41
# 2     1976  Alabama       AL           1         63        41
# 3     1976  Alabama       AL           1         63        41
# 4     1976  Alabama       AL           1         63        41
# ...    ...      ...      ...         ...        ...       ...
# 3735  2016  Wyoming       WY          56         83        68
# 3736  2016  Wyoming       WY          56         83        68
# 3737  2016  Wyoming       WY          56         83        68
# 3738  2016  Wyoming       WY          56         83        68
# 3739  2016  Wyoming       WY          56         83        68
#
#                     candidate                       party  writein  \
# 0               Carter, Jimmy                    democrat    False
# 1                Ford, Gerald                  republican    False
# ...

# %%
dff=df[(df.party == 'democrat') | (df.party == 'republican') | (df.party== 'democratic-farmer-labor')]
#we want the data of the states which went red or blue 
#so now dff becames our dataframe with party='republican' or party=='democrat' data
dff
# Out:
#       year          state state_po  state_fips  state_cen  state_ic  \
# 0     1976        Alabama       AL           1         63        41
# 1     1976        Alabama       AL           1         63        41
# 7     1976         Alaska       AK           2         94        81
# 8     1976         Alaska       AK           2         94        81
# 11    1976        Arizona       AZ           4         86        61
# ...    ...            ...      ...         ...        ...       ...
# 3719  2016  West Virginia       WV          54         55        56
# 3723  2016      Wisconsin       WI          55         35        25
# 3724  2016      Wisconsin       WI          55         35        25
# 3732  2016        Wyoming       WY          56         83        68
# 3733  2016        Wyoming       WY          56         83        68
#
#              candidate       party  writein  candidatevotes  totalvotes  \
# 0        Carter, Jimmy    democrat    False          659170     1182850
# ...

# %%
dff[dff.party=='democratic-farmer-labor']
#change the 'democratic-farmer-labour' to 'democrat'
# Out:
#       year      state state_po  state_fips  state_cen  state_ic  \
# 2210  2000  Minnesota       MN          27         41        33
# 2559  2004  Minnesota       MN          27         41        33
# 3225  2012  Minnesota       MN          27         41        33
#
#              candidate                    party  writein  candidatevotes  \
# 2210          Gore, Al  democratic-farmer-labor    False         1168266
# 2559       Kerry, John  democratic-farmer-labor    False         1445014
# 3225  Obama, Barack H.  democratic-farmer-labor    False         1546167
#
#       totalvotes   version
# 2210     2438685  20171015
# 2559     2828387  20171015
# 3225     2936561  20171015

# %%
#at index 2210 2559 3225 we have 'democratic-farmer-labour' 
dff.at[2210,'party']='democrat'
dff.at[2559,'party']='democrat'
dff.at[3225,'party']='democrat'
dff
# Out:
#       year          state state_po  state_fips  state_cen  state_ic  \
# 0     1976        Alabama       AL           1         63        41
# 1     1976        Alabama       AL           1         63        41
# 7     1976         Alaska       AK           2         94        81
# 8     1976         Alaska       AK           2         94        81
# 11    1976        Arizona       AZ           4         86        61
# ...    ...            ...      ...         ...        ...       ...
# 3719  2016  West Virginia       WV          54         55        56
# 3723  2016      Wisconsin       WI          55         35        25
# 3724  2016      Wisconsin       WI          55         35        25
# 3732  2016        Wyoming       WY          56         83        68
# 3733  2016        Wyoming       WY          56         83        68
#
#              candidate       party  writein  candidatevotes  totalvotes  \
# 0        Carter, Jimmy    democrat    False          659170     1182850
# ...

# %%
#now see if any 'democratic-party-labour' is still left
dff[dff.party=='democratic-farmer-labor']
#now , check 'writein'
# Out:
# Empty DataFrame
# Columns: [year, state, state_po, state_fips, state_cen, state_ic, candidate, party, writein, candidatevotes, totalvotes, version]
# Index: []

# %%
dff[dff.writein] #now, we cant remove this column as they are entries where 'writein'==True
# Out:
#       year     state state_po  state_fips  state_cen  state_ic  \
# 2544  2004  Maryland       MD          24         52        52
# 3414  2016   Arizona       AZ           4         86        61
# 3542  2016  Maryland       MD          24         52        52
# 3543  2016  Maryland       MD          24         52        52
#
#              candidate       party  writein  candidatevotes  totalvotes  \
# 2544             Other    democrat     True               7     2384238
# 3414               NaN    democrat     True              42     2573165
# 3542  Trump, Donald J.  republican     True             259     2781446
# 3543  Clinton, Hillary    democrat     True              78     2781446
#
#        version
# 2544  20171015
# 3414  20171015
# 3542  20171015
# 3543  20171015

# %%
#check for version if its same thruout
dff[dff.version != 20171015]
# Out:
# Empty DataFrame
# Columns: [year, state, state_po, state_fips, state_cen, state_ic, candidate, party, writein, candidatevotes, totalvotes, version]
# Index: []

# %%
#so no data row has version != 20171015
#so can delete it 
dff.drop(['version'],axis=1,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
dff
#so now 11 cols
# Out:
#       year          state state_po  state_fips  state_cen  state_ic  \
# 0     1976        Alabama       AL           1         63        41
# 1     1976        Alabama       AL           1         63        41
# 7     1976         Alaska       AK           2         94        81
# 8     1976         Alaska       AK           2         94        81
# 11    1976        Arizona       AZ           4         86        61
# ...    ...            ...      ...         ...        ...       ...
# 3719  2016  West Virginia       WV          54         55        56
# 3723  2016      Wisconsin       WI          55         35        25
# 3724  2016      Wisconsin       WI          55         35        25
# 3732  2016        Wyoming       WY          56         83        68
# 3733  2016        Wyoming       WY          56         83        68
#
#              candidate       party  writein  candidatevotes  totalvotes
# 0        Carter, Jimmy    democrat    False          659170     1182850
# ...

# %%
dff[dff.candidate.isnull()] #only 1 data row
#delete it from the dataset
dff.drop(index=3414,axis=0,inplace=True)

# %%
dff[dff.candidate == 'Other'] #only 1 data row
#delete it from the dataset
dff.drop(index=2544,axis=0,inplace=True)

# %%
#resetting our indexes from 0 onwards
dff.reset_index(drop=True) #drop=True is used to drop that previous column of indexes ie 0,1,7,8...
# Out:
#       year          state state_po  state_fips  state_cen  state_ic  \
# 0     1976        Alabama       AL           1         63        41
# 1     1976        Alabama       AL           1         63        41
# 2     1976         Alaska       AK           2         94        81
# 3     1976         Alaska       AK           2         94        81
# 4     1976        Arizona       AZ           4         86        61
# ...    ...            ...      ...         ...        ...       ...
# 1119  2016  West Virginia       WV          54         55        56
# 1120  2016      Wisconsin       WI          55         35        25
# 1121  2016      Wisconsin       WI          55         35        25
# 1122  2016        Wyoming       WY          56         83        68
# 1123  2016        Wyoming       WY          56         83        68
#
#              candidate       party  writein  candidatevotes  totalvotes
# 0        Carter, Jimmy    democrat    False          659170     1182850
# ...

# %%
dff[200:800]
# Out:
#       year           state state_po  state_fips  state_cen  state_ic  \
# 681   1980       Wisconsin       WI          55         35        25
# 682   1980       Wisconsin       WI          55         35        25
# 692   1980         Wyoming       WY          56         83        68
# 693   1980         Wyoming       WY          56         83        68
# 696   1984         Alabama       AL           1         63        41
# ...    ...             ...      ...         ...        ...       ...
# 2663  2004  South Carolina       SC          45         57        48
# 2669  2004    South Dakota       SD          46         45        37
# 2670  2004    South Dakota       SD          46         45        37
# 2674  2004       Tennessee       TN          47         62        54
# 2675  2004       Tennessee       TN          47         62        54
#
#             candidate       party  writein  candidatevotes  totalvotes
# ...

# %%
#Grouping the data according to states
grouped_data_by_state=dff.groupby('state')
grouped_data_by_state.count()
# Out:
#                       year  state_po  state_fips  state_cen  state_ic  \
# state
# Alabama                 22        22          22         22        22
# Alaska                  22        22          22         22        22
# Arizona                 22        22          22         22        22
# Arkansas                22        22          22         22        22
# California              22        22          22         22        22
# Colorado                22        22          22         22        22
# Connecticut             22        22          22         22        22
# Delaware                22        22          22         22        22
# District of Columbia    22        22          22         22        22
# Florida                 22        22          22         22        22
# Georgia                 22        22          22         22        22
# Hawaii                  22        22          22         22        22
# ...

# %%
#displaying data of Arizona state
grouped_data_by_state.get_group('Arizona')
# Out:
#       year    state state_po  state_fips  state_cen  state_ic  \
# 11    1976  Arizona       AZ           4         86        61
# 12    1976  Arizona       AZ           4         86        61
# 347   1980  Arizona       AZ           4         86        61
# 348   1980  Arizona       AZ           4         86        61
# 707   1984  Arizona       AZ           4         86        61
# 708   1984  Arizona       AZ           4         86        61
# 1030  1988  Arizona       AZ           4         86        61
# 1031  1988  Arizona       AZ           4         86        61
# 1320  1992  Arizona       AZ           4         86        61
# 1321  1992  Arizona       AZ           4         86        61
# 1688  1996  Arizona       AZ           4         86        61
# 1689  1996  Arizona       AZ           4         86        61
# 2055  2000  Arizona       AZ           4         86        61
# 2056  2000  Arizona       AZ           4         86        61
# ...

# %%
#displaying data of Maryland state
grouped_data_by_state.get_group('Maryland')
# Out:
#       year     state state_po  state_fips  state_cen  state_ic  \
# 122   1976  Maryland       MD          24         52        52
# 123   1976  Maryland       MD          24         52        52
# 475   1980  Maryland       MD          24         52        52
# 476   1980  Maryland       MD          24         52        52
# 819   1984  Maryland       MD          24         52        52
# 820   1984  Maryland       MD          24         52        52
# 1126  1988  Maryland       MD          24         52        52
# 1127  1988  Maryland       MD          24         52        52
# 1450  1992  Maryland       MD          24         52        52
# 1451  1992  Maryland       MD          24         52        52
# 1823  1996  Maryland       MD          24         52        52
# 1824  1996  Maryland       MD          24         52        52
# 2187  2000  Maryland       MD          24         52        52
# 2188  2000  Maryland       MD          24         52        52
# ...

# %%
#displaying data of Massachusetts state
grouped_data_by_state.get_group('Massachusetts')
# Out:
#       year          state state_po  state_fips  state_cen  state_ic  \
# 124   1976  Massachusetts       MA          25         14         3
# 125   1976  Massachusetts       MA          25         14         3
# 479   1980  Massachusetts       MA          25         14         3
# 480   1980  Massachusetts       MA          25         14         3
# 825   1984  Massachusetts       MA          25         14         3
# 826   1984  Massachusetts       MA          25         14         3
# 1131  1988  Massachusetts       MA          25         14         3
# 1132  1988  Massachusetts       MA          25         14         3
# 1455  1992  Massachusetts       MA          25         14         3
# 1456  1992  Massachusetts       MA          25         14         3
# 1830  1996  Massachusetts       MA          25         14         3
# 1831  1996  Massachusetts       MA          25         14         3
# 2195  2000  Massachusetts       MA          25         14         3
# ...

# %%
#displaying data of Minesota state
grouped_data_by_state.get_group('Minnesota')
#see now there is a bug
# democrats since 2000 have been listed as 'democratic-farmer-labor' in 'Minnesota' so gotta redo it all
#did it 
#now, i want to change those 'democratic-farmer-labor' to 'democrat' for uniformity
#did it
# Out:
#       year      state state_po  state_fips  state_cen  state_ic  \
# 141   1976  Minnesota       MN          27         41        33
# 142   1976  Minnesota       MN          27         41        33
# 493   1980  Minnesota       MN          27         41        33
# 494   1980  Minnesota       MN          27         41        33
# 840   1984  Minnesota       MN          27         41        33
# 841   1984  Minnesota       MN          27         41        33
# 1141  1988  Minnesota       MN          27         41        33
# 1142  1988  Minnesota       MN          27         41        33
# 1474  1992  Minnesota       MN          27         41        33
# 1475  1992  Minnesota       MN          27         41        33
# 1846  1996  Minnesota       MN          27         41        33
# 1847  1996  Minnesota       MN          27         41        33
# 2210  2000  Minnesota       MN          27         41        33
# 2211  2000  Minnesota       MN          27         41        33
# ...
